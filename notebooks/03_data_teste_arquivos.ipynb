# %% [markdown]
# ### Objetivo
#
# Testar conexão com os banco de dados

# %% [markdown]
# Importar bibliotecas e testar conexão com o banco de dados ou arquivos.

# %%
#import modules
import os
import pandas as pd
import datetime as dt
import time as t

import plotly.graph_objects as go
from plotly.offline import plot

# Current notebook path
path_notebooks = os.getcwd()

# Previous path
parent = os.path.dirname(path_notebooks)

# Path to the data folder
data_path = os.path.join(parent, "data")

# Ensure that the folder exist
os.makedirs(data_path, exist_ok=True)

# Full path to the file
file_path = os.path.join(data_path, "id_listname_dataframe.csv")

# Ensure the the file exist
if os.path.exists(file_path):
    print("Arquivo encontrado!")
    
    # Open the file using "pandas"
    df_listname = pd.read_csv(file_path)

else:
    print(f"Arquivo não encontrado em: {file_path}")
# Out:
# Arquivo encontrado!
